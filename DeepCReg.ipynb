# %% [markdown]
# # Imports

# %%
# !pip install -qq tensorflow-gpu==1.14 keras tqdm
# Out:
#      |████████████████████████████████| 377.0MB 42kB/s
#      |████████████████████████████████| 491kB 45.2MB/s
#      |████████████████████████████████| 3.2MB 53.5MB/s
# ERROR: tensorflow 1.15.0 has requirement tensorboard<1.16.0,>=1.15.0, but you'll have tensorboard 1.14.0 which is incompatible.
# ERROR: tensorflow 1.15.0 has requirement tensorflow-estimator==1.15.1, but you'll have tensorflow-estimator 1.14.0 which is incompatible.

# %%
import json
import csv
import pandas as pd
import numpy as np
from math import floor, ceil, sin, cos, radians, asin, sqrt, atan2

import itertools
import pickle

import matplotlib.pyplot as plt

from copy import deepcopy
from tqdm import tqdm
from pathlib import Path

# %% [markdown]
# # Functions

# %%
def get_RSS_list(gsm_ncells_str):
  """
  Parses the list of GSM_NCELLS read from the csv file 
  """
  gsm_ncells_str = gsm_ncells_str.replace('] [', '][').replace(']', '],').replace(' , ', ',').replace('[ ', '[').replace(' ]', ']')[:-2]
  gsm_ncells_str = '[' + gsm_ncells_str + ']'
  return json.loads(gsm_ncells_str)

def change_datatypes(list_dicts):
  """
  Changes the datatypes of some of the variables
  GSM_CID:    changed to int
  GSM_LAC:    changed to int
  GSM_RSS:    changed to int and converted to dBm
  GSM_NCELLS: each RSS reading is changed to dBm, and the primary cell is added
              as the first element to this list 
  """
  list_dicts_ = deepcopy(list_dicts)

  for i, dic in enumerate(list_dicts_):
    dic['GSM_CID'] = int(dic['GSM_CID'])
    dic['GSM_LAC'] = int(dic['GSM_LAC'])
    dic['GSM_RSS'] = -113 + 2 * int(dic['GSM_RSS'])
    if dic['GSM_RSS'] == 85:
      dic['GSM_RSS'] = 0
    dic['GSM_NCELLS'] = get_RSS_list(dic['GSM_NCELLS'])
    dic['accuracy'] = float(dic['accuracy'])
    dic['latitude'] = float(dic['latitude'])
    dic['longitude'] = float(dic['longitude'])
    
    lst = []
    for elem in dic['GSM_NCELLS']:

      if elem[0] == dic['GSM_CID']:
          continue

      elem[2] = -113 + 2 * elem[2]
      if elem[2] == 85:         ## Unknown RSS, skip
        continue

      lst.append(elem[:3])
    lst.insert(0, [dic['GSM_CID'], dic['GSM_LAC'], dic['GSM_RSS']])

    dic['GSM_NCELLS'] = lst
  return list_dicts_

def get_unique_cells(list_dicts):
  """
  Gets a list of all the unique cells in the dataset
  """
  unique_cells = []
  for elem in list_dicts:
    for lst in elem['GSM_NCELLS']:
      if lst[0] not in unique_cells:
        unique_cells.append(lst[0])
  return unique_cells

def get_cell_indxs(list_dicts=None, cells=None):
  """
  Creates a mapping from cell number to it's index in the input layer
  """
  if cells is None:
    cells = get_unique_cells(list_dicts)
    
  cells = sorted(cells)

  cell_indxs = {}
  for i, cell in enumerate(cells):
    cell_indxs[cell] = i

  return cell_indxs

def combine_cells(list_dicts, cell_indxs=None, zero_value=-108):
  """
  Takes the list of dictionaries and coverts the all the RSS readings of each row 
  to one list using the cell_indxs mapping
  """
  if cell_indxs is None:
      cell_indxs = get_cell_indxs(list_dicts)
  list_dicts_ = []
  for i,row in enumerate(deepcopy(list_dicts)):
    GSM_NCELLS = np.zeros(len(cell_indxs.keys()), dtype='int')
    for cell in row['GSM_NCELLS']:
      try:
        if GSM_NCELLS[cell_indxs[cell[0]]] != 0:
          print(i, row)
        GSM_NCELLS[cell_indxs[cell[0]]] = cell[2]
      except:
        pass
    
    row['CELLS_COUNT'] = np.count_nonzero(GSM_NCELLS)
    if row['CELLS_COUNT'] == 0:
      continue
    GSM_NCELLS[GSM_NCELLS == 0] = zero_value
    row['GSM_NCELLS'] = GSM_NCELLS
    
    
    list_dicts_.append(row)
  return list_dicts_


#==================================================LABELS=============================================
def get_min_max_coords(list_dicts):
  """
  Takes the list of dictionaries and get the minimum and maximum longitude and latitude
  """
  min_lat, min_lon, max_lat, max_lon = 500, 500, -500, -500

  for dct in list_dicts:
    lat = dct['latitude']
    lon = dct['longitude']
    
    if lat < min_lat:
      min_lat = lat
    if lat > max_lat:
      max_lat = lat
      
    if lon < min_lon:
      min_lon = lon
    if lon > max_lon:
      max_lon = lon
    
  return (min_lat, max_lat), (min_lon, max_lon)


def get_distance(coords1, coords2):
  lat1, lon1, lat2, lon2 = map(radians, [coords1[0], coords1[1], coords2[0], coords2[1]]) 
  dlon = radians(coords2[1] - coords1[1]) 
  dlat = radians(coords2[0] - coords1[0])
  a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
  c = 2 * atan2(sqrt(a), sqrt(1-a))
  km = 6371* c
  return km*1000

def get_gridcell2(coords, min_max_coords, num_rows, num_cols, grid_cell_length=100):
  lat_sw, lon_sw, lat_ne, lon_ne = min_max_coords
  lon_nw, lon_se = lon_sw, lon_ne
  lat_se, lat_nw = lat_sw, lat_ne
  
  se = (lat_se, lon_se)
  sw = (lat_sw, lon_sw)
  ne = (lat_ne, lon_ne)
  nw = (lat_nw, lon_nw)

  lat_test, lon_test = coords
  
  bottom = (lat_sw, lon_test)
  left = (lat_test, lon_nw)
  top=(lat_nw, lon_test)
  
  row_dist, col_dist = get_distance(left, sw), get_distance(bottom, sw)
  row = int(row_dist // grid_cell_length)
  col = int(col_dist // grid_cell_length)
  
  cell = row * num_cols + col
  
  return cell
  
def assign_cells_to_data_2(list_dicts, min_max_coords, grid_cell_length=100):  
  lat_sw, lon_sw, lat_ne, lon_ne = min_max_coords
  lat_se, lon_se = lat_sw, lon_ne
  lat_nw, lon_nw = lat_ne, lon_sw
  
  se = (lat_se, lon_se)
  sw = (lat_sw, lon_sw)
  ne = (lat_ne, lon_ne)
  nw = (lat_nw, lon_nw)
  
  ver_distance1 = get_distance(sw, nw)
  ver_distance2 = get_distance(se, ne)

  hor_distance1 = get_distance(sw, se)
  hor_distance2 = get_distance(nw, ne)

  avg_hor_distance = (hor_distance1 + hor_distance2) / 2
  avg_ver_distance = (ver_distance1 + ver_distance2) / 2

  num_cols = np.ceil(avg_hor_distance / grid_cell_length)
  num_rows = np.ceil(avg_ver_distance / grid_cell_length)
  
  
  num_rows = int(num_rows)
  num_cols = int(num_cols)
  for row in list_dicts:
    row['label'] = get_gridcell2((row['latitude'], row['longitude']), min_max_coords, num_rows, num_cols, grid_cell_length=grid_cell_length)
  return num_rows, num_cols
#==========================================================================================
def create_data_matrix(list_dicts, output_len, get_onehot=True):
  """
  Takes a list of dictionaries as input and return two matrices, one for
  the data and one for the labels (id of the grid cells)
  """
  number_gsm_cells = list_dicts[0]['GSM_NCELLS'].shape[0]
  x = np.empty((list_dicts.shape[0], number_gsm_cells), dtype='int')
  y = np.empty((list_dicts.shape[0], output_len), dtype='uint8')
  y_nums = np.empty((len(list_dicts), )).astype('uint32')
 
  for i, elem in enumerate(list_dicts):
    x[i] = elem['GSM_NCELLS'].reshape(1, -1)
    if get_onehot:
      y_one_hot = np.zeros(output_len, dtype='int').reshape(1, -1)[0]
      y_one_hot[elem['label']] = 1
      y[i] = y_one_hot
    else:
      y[i] = 0
    y_nums[i] = elem['label']
  y_coords = get_coords_labels(list_dicts)
  timestamps = get_timestamps(list_dicts)
  return (x, y, y_nums, y_coords, timestamps)

def get_all_key_elements_from_dicts(dicts, key):
  num_rows, num_cols = len(dicts), dicts[0][key].shape[0]
  data = np.empty((num_rows, num_cols))
  for i, dic in enumerate(dicts):
    data[i] = dic[key]
    
  return data

def get_unique_dicts(dicts, key):
  all_rss = get_all_key_elements_from_dicts(dicts, key)
  _, idxs = np.unique(all_rss, axis=0, return_index=True)
  
  unique_dicts = []
  for idx in idxs:
    unique_dicts.append(dicts[idx])
    
  return unique_dicts

def train_val_test_split(list_dicts, val_ratio=0.2, test_ratio=0.2, shuffle=True):
  """
  Performs train-val-test split according to the given ratios
  """
  train_ratio = 1 - val_ratio - test_ratio
  number_elements = len(list_dicts)
  idxs = np.arange(number_elements)
  if shuffle:
    np.random.shuffle(idxs)
  list_dicts = np.array(list_dicts)[idxs]
  
  train_start ,train_end = 0, floor(number_elements * train_ratio)
  val_start, val_end = ceil(number_elements * train_ratio), floor(number_elements * (train_ratio + val_ratio))
  test_start, test_end = ceil(number_elements * (train_ratio + val_ratio)), number_elements
  
  if train_end != val_start:
      val_start -= 1

  if val_end != test_start:
      test_start -= 1

  train = list_dicts[train_start:train_end]
  val =  list_dicts[val_start:val_end]
  test = list_dicts[test_start:test_end]
  
  return train, val, test

def get_coords_labels(list_dicts):
  """
  Takes a list of dicts as inputs and returns the GPS coordinates of each instance.
  """
  labels = np.empty((0, 2))
  for elem in list_dicts:
    labels = np.vstack((labels, np.array([elem['latitude'], elem['longitude']])))
  return labels

def get_timestamps(list_dicts):
    timestamps = np.empty((len(list_dicts), )).astype('str')
    for i, elem in enumerate(list_dicts):
        timestamps[i] = elem['gmtTimestamp']
    return timestamps

def my_std(vals):
  if vals.shape[0] == 0:
    return 0
  diff_squared = np.sum((vals - np.mean(vals)) ** 2)
  sqrd = np.sqrt(diff_squared / (vals.shape[0]) )
  return sqrd

def get_center_of_mass(num_grid_cells, y_nums, y_coords):
  center_of_mass = np.empty((num_grid_cells, 2))
  missing_flag, missing_idx = False, 0
  for i in range(num_grid_cells):
    idxs = np.where(y_nums==i)[0]

    if idxs.shape[0] == 0:
      if i > 0:
        center_of_mass[i] = center_of_mass[i-1]
      else:
        missing_flag = True
      continue
    samples = y_coords[idxs]
    center = np.mean(samples, axis=0)
    center_of_mass[i] = center
  
  if missing_flag:
    center_of_mass[missing_idx] = center_of_mass[missing_idx + 1]
  return center_of_mass

def get_prediction_coords(predictions_nums, center_of_mass):
  predictions_coords = np.empty((predictions_nums.shape[0], 2))
  
  for i, pred in enumerate(predictions_nums):
    predictions_coords[i] = center_of_mass[pred]
  
  return predictions_coords
    
def calculate_localization_errors(prediction_coords, true_coords):
  errors = np.empty(prediction_coords.shape[0])
  
  for i, (pred, true) in enumerate(zip(prediction_coords, true_coords)):
    errors[i] = get_distance(pred, true)
  
  return errors

def get_xy_coords(nums, rows, cols):
  xy_coords = []
  for num in nums:
    i, j = num / cols, num % cols
    xy_coords.append((i, j))
  return xy_coords

def get_manhattan_distance(x1, y1, x2, y2):
  return np.abs(x1 - x2) + np.abs(y1 - y2)

def calculate_accuracy(rows, cols, pred_nums, true_nums, rank=1):
  count_correct = 0
  count_all = pred_nums.shape[0]
  true_xy = get_xy_coords(true_nums, rows, cols)
  pred_xy = get_xy_coords(pred_nums, rows, cols)
  for xy1, xy2 in zip(true_xy, pred_xy):
    manhattan_dist = get_manhattan_distance(*xy1, *xy2)
    if manhattan_dist <= rank:
      count_correct += 1
  return count_correct/count_all

def get_ground_truth_error(data, center_of_mass):
  errors = np.zeros(data[0].shape[0])
  for i, (label, coords) in enumerate(zip(data[2], data[3])):
    label = int(label)
    lat,lon = coords[0], coords[1]
    center = center_of_mass[label]
    error = get_distance((lat, lon), center)
    errors[i] = error
  return errors


def load_data_from_csv(file_paths, keys, skip_rows, header_row_index=14, required_data=None):
  if type(file_paths) is not list:
    file_paths = list(file_paths)
    keys       = list(keys)
    skip_rows  = list(skip_rows)
    
  assert len(file_paths) == len(keys), 'Number of files must match number of keys'
  assert len(file_paths) == len(skip_rows), 'Number of files must match number of skip_rows'
  
  if required_data is None:
    required_data = ['gmtTimestamp', 'latitude', 'longitude', 'accuracy', 'GSM_CID', 'GSM_LAC', 'GSM_RSS', 'GSM_NCELLS']
  
  all_data = {}

  for key, path, skip_row in zip(keys, file_paths, skip_rows):
      data = []
      with open(path, newline='') as csvfile:
          reader = csv.DictReader(csvfile, fieldnames=[])
          for row in reader:
              data.append(row)

      data_keys = data[header_row_index][None]
      positions = [i for i in range(len(data_keys)) if data_keys[i] in required_data]

      list_dicts = []
      for i in tqdm(range(skip_row, len(data))):
          row = {}
          for j in range(len(positions)):
              row[required_data[j]] = data[i][None][positions[j]]

          list_dicts.append(row)
      all_data[key] = {}
      all_data[key]['original'] = list_dicts
      print(f'Finished reading data for key: {key}')
      
  return all_data


def get_preds_from_model(model, data, centers_of_mass):
  preds = model.predict(data)
  preds_nums = np.argmax(preds, axis=1)
  preds_coords = get_prediction_coords(preds_nums, centers_of_mass)
  
  return preds_nums, preds_coords

def normalize_labels(y_train, y_val, y_holdout=None):
  minimum = np.min(y_train, axis=0)
  range = np.max(y_train, axis=0) - minimum
  y_train = np.divide(y_train - minimum, range)
  y_val   = np.divide(y_val - minimum, range)
  if y_holdout is not None:
    y_holdout = np.divide(y_holdout - minimum, range)
  
  return minimum, range, y_train, y_val, y_holdout

def get_square_samples(X, num_channels=3):
    num_cell_towers = X.shape[1]
    X_square = np.empty((X.shape[0], num_channels, num_cell_towers,num_cell_towers))
    for i, sample in enumerate(X):
        tmps = np.empty((1,num_channels, num_cell_towers, num_cell_towers))
        tmp = tmps[0]
        
        tmp[0] = np.divide(sample.reshape(-1,1), sample.reshape(1,-1))
        if num_channels > 1:
            tmp[1] = sample.reshape(-1,1) - sample.reshape(1,-1)
            
        if num_channels > 2:
            tmp[2] = np.tile(sample, (num_cell_towers, 1))
      
        X_square[i] = tmps
        
    X_square = np.moveaxis(X_square, 1, -1)
    return (X_square, )

# %% [markdown]
# # Getting the data

# %%
# !wget https://www.dropbox.com/s/wq3kzs5m4r3u2gl/Testbed2.rar
# !unrar e Testbed2.rar
# Out:
# --2020-01-25 14:54:40--  https://www.dropbox.com/s/wq3kzs5m4r3u2gl/Testbed2.rar
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.8.1, 2620:100:6018:1::a27d:301
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.8.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/wq3kzs5m4r3u2gl/Testbed2.rar [following]
# --2020-01-25 14:54:41--  https://www.dropbox.com/s/raw/wq3kzs5m4r3u2gl/Testbed2.rar
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com/cd/0/inline/Aw056VFAMn8rdCdiDFSj3vMkbRmIIB_RVT6t7ZHtovaXao0SfTsa-eXyZ-TGJEm1RCNVvjx8Cxg7SezaEqV7Jyer1ZiDRekJxLKwfdSif7nlDf-s1Id-zYv_G9RMKpDHnO8/file# [following]
# --2020-01-25 14:54:41--  https://uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com/cd/0/inline/Aw056VFAMn8rdCdiDFSj3vMkbRmIIB_RVT6t7ZHtovaXao0SfTsa-eXyZ-TGJEm1RCNVvjx8Cxg7SezaEqV7Jyer1ZiDRekJxLKwfdSif7nlDf-s1Id-zYv_G9RMKpDHnO8/file
# Resolving uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com (uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com)... 162.125.3.6, 2620:100:601b:6::a27d:806
# Connecting to uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com (uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com)|162.125.3.6|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: /cd/0/inline2/Aw19cxo8WYt4qutP8DYkTMm1urGnqqKsT0485ZvKMqClp_YOVpCG9RgPTDmLOPaXJ0DKxIztkOK942gKlaA6PRmhMPY6rC_7zvLc5u3jm9OPcFqy5mzMeOf1TcfIBo2LQ6Mk7hsozyxDvuURo7NvAYHfIkw9FJT73zJ_wYGEyHJHgtY7OZx_xk6MxIchwskxPpDxQfo3PPwLrTEhikr4LKQYp0VCOE5sbCKqRnW1o4Weq0VPFsiKDBW-hjUNCSBzXrYDIMYcPvAmkjg5TlGTkH6FArmdJhE2rWL8bqim5yB8zhrRknGU5t8tZsSvW5V2UI_wbDQ468G7x-4nVkIFhXtHlQAXT2rKmOfsP7FJRanp2g/file [following]
# --2020-01-25 14:54:41--  https://uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com/cd/0/inline2/Aw19cxo8WYt4qutP8DYkTMm1urGnqqKsT0485ZvKMqClp_YOVpCG9RgPTDmLOPaXJ0DKxIztkOK942gKlaA6PRmhMPY6rC_7zvLc5u3jm9OPcFqy5mzMeOf1TcfIBo2LQ6Mk7hsozyxDvuURo7NvAYHfIkw9FJT73zJ_wYGEyHJHgtY7OZx_xk6MxIchwskxPpDxQfo3PPwLrTEhikr4LKQYp0VCOE5sbCKqRnW1o4Weq0VPFsiKDBW-hjUNCSBzXrYDIMYcPvAmkjg5TlGTkH6FArmdJhE2rWL8bqim5yB8zhrRknGU5t8tZsSvW5V2UI_wbDQ468G7x-4nVkIFhXtHlQAXT2rKmOfsP7FJRanp2g/file
# Reusing existing connection to uc5e019e6323077d38cb6e118f20.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7258737 (6.9M) [application/rar]
# Saving to: ‘Testbed2.rar’
#
# Testbed2.rar        100%[===================>]   6.92M  --.-KB/s    in 0.1s
#
# 2020-01-25 14:54:42 (50.4 MB/s) - ‘Testbed2.rar’ saved [7258737/7258737]
#
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Testbed2.rar
#
#   OK
# All OK

# %% [markdown]
# # Data

# %%
file_path1 = 'Testbed2.csv'                                   # Path of the csv file
file_paths = [file_path1]


header_row_index = 14                                         # The index of the row that contains the columns' names
skip_rows = [200]                                             # The number of rows containing invalid data to skip
keys      = ['1']


all_data = load_data_from_csv(file_paths, 
                              keys,
                              skip_rows,
                              header_row_index=header_row_index)
# Out:
# 100%|██████████| 89327/89327 [00:00<00:00, 415318.92it/s]
# Finished reading data for key: 1

# %%
all_data['1']['changed']  = change_datatypes(all_data['1']['original'])

# %%
cell_indxs1 = get_cell_indxs(all_data['1']['changed'])
all_data['1']['combined'] = combine_cells(all_data['1']['changed'], cell_indxs=cell_indxs1, zero_value=-108)

# %%
grid_cell_size = 400              # Width/Height of each grid cell

lats, lons = get_min_max_coords(all_data['1']['combined'])
rows, cols = assign_cells_to_data_2(all_data['1']['combined'], (lats[0], lons[0], lats[1], lons[1]), grid_cell_size)
num_grid_cells = rows * cols
print(f'# of rows {rows}\t# of columns: {cols}\t# of grid cells: {num_grid_cells}')
# Out:
# 3 5

# %%
# Split the data into train, validation and test sets.
np.random.seed(42)
all_data['1']['train'], all_data['1']['val'], all_data['1']['test'] = train_val_test_split(all_data['1']['combined'], 0.1, 0.2, True) # pass list of dicts, val_ratio, test_ratio, shuffle=True/False

# Create the data matrices for each set
all_data['1']['train'] = create_data_matrix(all_data['1']['train'], output_len=num_grid_cells)
all_data['1']['val']   = create_data_matrix(all_data['1']['val'], output_len=num_grid_cells)
all_data['1']['test']  = create_data_matrix(all_data['1']['test'], output_len=num_grid_cells)

# %%
# Get the center of mass of each cell in the grid
center_of_mass = get_center_of_mass(all_data['1']['train'][1].shape[1], all_data['1']['train'][2], all_data['1']['train'][3])

# Get the lowest achievable error on the train and validation set
trn_errors = get_ground_truth_error(all_data['1']['train'], center_of_mass)
val_errors = get_ground_truth_error(all_data['1']['val'], center_of_mass)

print('Lowest achievable median localization error using the classifcation approach')
print(f'Train median: {np.median(trn_errors):.4f}m\tVal median: {np.median(val_errors):.4f}m')
# Out:
# Train median: 112.48854291539558	Val median: 113.84045271866687

# %%
# Create the 3 channels
num_channels = 3
for key in ['1']:
  for split in ['train', 'val', 'test']:
    square_samples = get_square_samples(all_data[key][split][0], num_channels=num_channels)

    if len(all_data[key][split]) > 5:
      all_data[key][split] = all_data[key][split][:-1]

    all_data[key][split] += square_samples

# %% [markdown]
# # DeepCReg

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, Conv1D, Dropout, Activation, MaxPooling2D
from keras.optimizers import Adam, sgd, SGD
import keras.backend as K
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %% [markdown]
# ## Callbacks

# %%
from keras.callbacks import Callback
from keras.callbacks import LearningRateScheduler

class RegressorsCallback(Callback):
  """
  Logs the localization error of the model on the training and validation sets
  during training and saves the models that achieve the lowest localization error.
  """
  def __init__(self, data,min_, range_, title, data_idx=-1):
    self.X        = data[data_idx]
    self.y_coords = data[3]
    
    self.min = min_
    self.range = range_
    
    self.title = title
    self.best_median = 1e5
    self.medians = []
    
  def on_train_begin(self, logs=None):
    self.best_err    = 1e5
    self.best_median = 1e5
    
    self.errors    = []
    self.medians = []

  
  def on_epoch_end(self, epoch, logs=None):
    pred_coords = np.multiply(self.model.predict(self.X), self.range) + self.min
    errors = calculate_localization_errors(pred_coords, self.y_coords)
    
    print(f'{self.title}')
    print(f'Localization Error: {np.min(errors):5f}\t{np.percentile(errors,25):5f}\t{np.median(errors):.5f}\t'\
      f'{np.percentile(errors,75):.5f}\t{np.max(errors):.5f}')
    
    self.medians.append(np.median(errors))
          
    if np.median(errors) < self.best_median:
      path = Path('.')
      for p in path.glob(f'best_{self.title}_median*'):
        p.unlink()
        
      self.best_median = np.median(errors)
      self.model.save(f'best_{self.title}_median-{self.best_median:.4f}_epoch-{epoch}', overwrite=True)

# %% [markdown]
# ## Model

# %%
X_train, y_train, y_train_nums       = all_data['1']['train'][-1], all_data['1']['train'][3], all_data['1']['train'][2]
X_val, y_val, y_val_nums             = all_data['1']['val'][-1], all_data['1']['val'][3], all_data['1']['val'][2]
X_test, y_test, y_test_num           = all_data['1']['test'][-1], all_data['1']['test'][3], all_data['1']['test'][2]

# %%
min_, range_, y_train_normalized, y_val_normalized, y_test = normalize_labels(y_train, y_val, y_test)

# %%
keras.backend.set_image_data_format('channels_last')

num_cells = X_train.shape[1]
input_shape = (num_cells, num_cells, num_channels)

cnn_model = Sequential()
cnn_model.add(Conv2D(128, kernel_size=(X_train.shape[1], 5), activation='relu', input_shape=input_shape))
cnn_model.add(Conv2D(256, kernel_size=(1,5), activation='relu'))
cnn_model.add(Conv2D(512, kernel_size=(1,5), activation='relu'))
cnn_model.add(Flatten())
cnn_model.add(Dense(256))
cnn_model.add(Activation('relu'))
cnn_model.add(Dense(128))
cnn_model.add(Activation('relu'))
cnn_model.add(Dense(64))
cnn_model.add(Activation('relu'))
cnn_model.add(Dense(y_train.shape[1], activation='sigmoid'))
cnn_model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 1, 54, 128)        111488
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 1, 50, 256)        164096
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 1, 46, 512)        655872
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 23552)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               6029568
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# activation_2 (Activation)    (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# activation_3 (Activation)    (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 7,002,306
# Trainable params: 7,002,306
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint

def LRScheduler(epoch, current_lr):
  if epoch != 0 and epoch % 25 == 0:
    current_lr *= 0.1
  return current_lr

trn_clb = RegressorsCallback(all_data['1']['train'], min_, range_, title='train-reg')
val_clb = RegressorsCallback(all_data['1']['val'], min_, range_, title='validation-reg')
lr_sched = LearningRateScheduler(LRScheduler, verbose=1)
callbacks = [trn_clb, val_clb, lr_sched]

epochs=150
bs=64
initial_lr = 1e-4

# %%
optimizer = Adam(lr=initial_lr)
cnn_model.compile(optimizer, loss='mse', metrics=['mse'])
cnn_model.fit(X_train, y_train_normalized, batch_size=bs, epochs=epochs,
              validation_data=(X_val, y_val_normalized), callbacks=callbacks)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 62528 samples, validate on 8933 samples
# Epoch 1/150
#
# Epoch 00001: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 26s 422us/step - loss: 0.0127 - mean_squared_error: 0.0127 - val_loss: 5.3536e-04 - val_mean_squared_error: 5.3536e-04
# train-reg
# Localization Error: 0.724858	16.511412	29.03612	45.94466	181.84740
# validation-reg
# Localization Error: 0.724858	16.588085	29.15687	46.57020	179.03626
# Epoch 2/150
#
# Epoch 00002: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 277us/step - loss: 2.7255e-04 - mean_squared_error: 2.7255e-04 - val_loss: 4.8839e-04 - val_mean_squared_error: 4.8839e-04
# train-reg
# Localization Error: 0.745221	16.523327	27.20729	42.81160	202.41293
# validation-reg
# Localization Error: 0.745221	16.506456	27.04118	43.37988	193.87932
# Epoch 3/150
#
# Epoch 00003: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 278us/step - loss: 2.1495e-04 - mean_squared_error: 2.1495e-04 - val_loss: 2.2612e-04 - val_mean_squared_error: 2.2612e-04
# train-reg
# Localization Error: 0.403234	12.079854	19.27751	29.15596	143.22387
# validation-reg
# Localization Error: 0.403234	12.073768	19.40819	29.26692	143.22387
# Epoch 4/150
#
# Epoch 00004: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 18s 282us/step - loss: 1.8554e-04 - mean_squared_error: 1.8554e-04 - val_loss: 2.7524e-04 - val_mean_squared_error: 2.7524e-04
# train-reg
# Localization Error: 0.436594	12.590866	19.78330	28.80413	171.88125
# validation-reg
# Localization Error: 0.610811	12.690728	19.98480	29.20521	165.83454
# Epoch 5/150
#
# Epoch 00005: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 18s 280us/step - loss: 1.7242e-04 - mean_squared_error: 1.7242e-04 - val_loss: 1.3966e-04 - val_mean_squared_error: 1.3966e-04
# train-reg
# Localization Error: 0.146938	9.165162	14.67942	22.53512	152.04412
# validation-reg
# Localization Error: 0.394442	9.300181	14.76177	22.84151	152.04412
# Epoch 6/150
#
# Epoch 00006: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 278us/step - loss: 1.5346e-04 - mean_squared_error: 1.5346e-04 - val_loss: 1.3679e-04 - val_mean_squared_error: 1.3679e-04
# train-reg
# Localization Error: 0.130002	8.364734	13.75442	21.84334	139.16938
# validation-reg
# Localization Error: 0.130002	8.318111	13.82898	22.37732	117.67861
# Epoch 7/150
#
# Epoch 00007: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.3550e-04 - mean_squared_error: 1.3550e-04 - val_loss: 1.8195e-04 - val_mean_squared_error: 1.8195e-04
# train-reg
# Localization Error: 0.223320	10.444786	17.61546	25.64674	151.88180
# validation-reg
# Localization Error: 0.392277	10.482087	17.81065	25.66577	102.47205
# Epoch 8/150
#
# Epoch 00008: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.1744e-04 - mean_squared_error: 1.1744e-04 - val_loss: 1.1230e-04 - val_mean_squared_error: 1.1230e-04
# train-reg
# Localization Error: 0.038482	7.360581	12.00425	18.20102	131.82237
# validation-reg
# Localization Error: 0.038482	7.414065	12.19105	18.68172	118.38755
# Epoch 9/150
#
# Epoch 00009: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.0978e-04 - mean_squared_error: 1.0978e-04 - val_loss: 9.9013e-05 - val_mean_squared_error: 9.9013e-05
# train-reg
# Localization Error: 0.147119	7.640431	12.61464	18.97161	131.56659
# validation-reg
# Localization Error: 0.147119	7.808752	12.68106	19.16635	131.56659
# Epoch 10/150
#
# Epoch 00010: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 275us/step - loss: 9.0499e-05 - mean_squared_error: 9.0499e-05 - val_loss: 9.8673e-05 - val_mean_squared_error: 9.8673e-05
# train-reg
# Localization Error: 0.162681	8.128907	12.39195	18.45289	136.99879
# validation-reg
# Localization Error: 0.162681	8.021364	12.47286	18.43900	88.65823
# Epoch 11/150
#
# Epoch 00011: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 274us/step - loss: 8.7139e-05 - mean_squared_error: 8.7139e-05 - val_loss: 5.9965e-05 - val_mean_squared_error: 5.9965e-05
# train-reg
# Localization Error: 0.184214	5.058305	8.57757	13.40794	126.07682
# validation-reg
# Localization Error: 0.184214	5.097957	8.63104	13.49639	78.93110
# Epoch 12/150
#
# Epoch 00012: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 274us/step - loss: 7.7527e-05 - mean_squared_error: 7.7527e-05 - val_loss: 6.7809e-05 - val_mean_squared_error: 6.7809e-05
# train-reg
# Localization Error: 0.137527	5.288944	8.80798	14.21598	140.12458
# validation-reg
# Localization Error: 0.137527	5.250628	8.78433	14.39889	109.98690
# Epoch 13/150
#
# Epoch 00013: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 276us/step - loss: 7.2332e-05 - mean_squared_error: 7.2332e-05 - val_loss: 7.9389e-05 - val_mean_squared_error: 7.9389e-05
# train-reg
# Localization Error: 0.077886	6.858724	10.81355	16.47740	117.36709
# validation-reg
# Localization Error: 0.077886	6.933097	10.94424	16.66351	95.59208
# Epoch 14/150
#
# Epoch 00014: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 275us/step - loss: 6.5109e-05 - mean_squared_error: 6.5109e-05 - val_loss: 7.3340e-05 - val_mean_squared_error: 7.3340e-05
# train-reg
# Localization Error: 0.074086	5.943115	9.92972	15.53581	113.91088
# validation-reg
# Localization Error: 0.074086	6.041014	10.11233	15.76991	79.48519
# Epoch 15/150
#
# Epoch 00015: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 276us/step - loss: 6.3268e-05 - mean_squared_error: 6.3268e-05 - val_loss: 5.5133e-05 - val_mean_squared_error: 5.5133e-05
# train-reg
# Localization Error: 0.253956	5.162994	8.48520	13.36134	119.11865
# validation-reg
# Localization Error: 0.374023	5.233131	8.63723	13.56973	97.87691
# Epoch 16/150
#
# Epoch 00016: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 272us/step - loss: 5.5888e-05 - mean_squared_error: 5.5888e-05 - val_loss: 5.6496e-05 - val_mean_squared_error: 5.6496e-05
# train-reg
# Localization Error: 0.089906	5.046090	8.11756	12.80400	109.80794
# validation-reg
# Localization Error: 0.089906	5.179926	8.28271	12.89417	70.40334
# Epoch 17/150
#
# Epoch 00017: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 271us/step - loss: 5.2218e-05 - mean_squared_error: 5.2218e-05 - val_loss: 6.1036e-05 - val_mean_squared_error: 6.1036e-05
# train-reg
# Localization Error: 0.145832	5.922664	9.67205	14.64685	99.00357
# validation-reg
# Localization Error: 0.145832	5.955598	9.93047	14.84089	74.97983
# Epoch 18/150
#
# Epoch 00018: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 271us/step - loss: 5.0630e-05 - mean_squared_error: 5.0630e-05 - val_loss: 6.0081e-05 - val_mean_squared_error: 6.0081e-05
# train-reg
# Localization Error: 0.068989	4.875579	8.39916	13.24402	91.22015
# validation-reg
# Localization Error: 0.068989	5.001412	8.56414	13.67558	91.22015
# Epoch 19/150
#
# Epoch 00019: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 271us/step - loss: 4.9855e-05 - mean_squared_error: 4.9855e-05 - val_loss: 4.2916e-05 - val_mean_squared_error: 4.2916e-05
# train-reg
# Localization Error: 0.169766	4.065136	6.91738	11.05731	92.23829
# validation-reg
# Localization Error: 0.169766	4.157447	7.01091	11.24600	84.16733
# Epoch 20/150
#
# Epoch 00020: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 277us/step - loss: 4.9071e-05 - mean_squared_error: 4.9071e-05 - val_loss: 4.3866e-05 - val_mean_squared_error: 4.3866e-05
# train-reg
# Localization Error: 0.213256	4.441061	7.32645	11.56018	83.75966
# validation-reg
# Localization Error: 0.319617	4.505289	7.56838	11.91847	77.39983
# Epoch 21/150
#
# Epoch 00021: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 269us/step - loss: 4.3949e-05 - mean_squared_error: 4.3949e-05 - val_loss: 4.3169e-05 - val_mean_squared_error: 4.3169e-05
# train-reg
# Localization Error: 0.040879	4.274990	7.02777	11.29213	97.35903
# validation-reg
# Localization Error: 0.040879	4.348075	7.14812	11.53668	74.40399
# Epoch 22/150
#
# Epoch 00022: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 273us/step - loss: 4.3956e-05 - mean_squared_error: 4.3956e-05 - val_loss: 4.6379e-05 - val_mean_squared_error: 4.6379e-05
# train-reg
# Localization Error: 0.176154	4.952614	7.61249	11.50322	89.34895
# validation-reg
# Localization Error: 0.176154	4.980335	7.74570	11.76682	75.84786
# Epoch 23/150
#
# Epoch 00023: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 270us/step - loss: 4.2392e-05 - mean_squared_error: 4.2392e-05 - val_loss: 3.6359e-05 - val_mean_squared_error: 3.6359e-05
# train-reg
# Localization Error: 0.071094	3.519279	6.15041	10.03652	91.32291
# validation-reg
# Localization Error: 0.077316	3.609850	6.33869	10.26280	66.93225
# Epoch 24/150
#
# Epoch 00024: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 271us/step - loss: 4.1816e-05 - mean_squared_error: 4.1816e-05 - val_loss: 3.8567e-05 - val_mean_squared_error: 3.8567e-05
# train-reg
# Localization Error: 0.122004	3.794996	6.24968	10.27368	79.77940
# validation-reg
# Localization Error: 0.122004	3.811101	6.27506	10.54361	69.25798
# Epoch 25/150
#
# Epoch 00025: LearningRateScheduler setting learning rate to 9.999999747378752e-05.
# 62528/62528 [==============================] - 17s 273us/step - loss: 3.9930e-05 - mean_squared_error: 3.9930e-05 - val_loss: 4.9921e-05 - val_mean_squared_error: 4.9921e-05
# train-reg
# Localization Error: 0.219080	5.350678	8.59950	12.71121	96.63241
# validation-reg
# Localization Error: 0.350165	5.445367	8.65602	12.82553	96.63241
# Epoch 26/150
#
# Epoch 00026: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 271us/step - loss: 2.0963e-05 - mean_squared_error: 2.0963e-05 - val_loss: 2.0682e-05 - val_mean_squared_error: 2.0682e-05
# train-reg
# Localization Error: 0.057048	1.708237	3.26350	6.57159	77.91989
# validation-reg
# Localization Error: 0.057048	1.712208	3.36183	6.84307	71.14844
# Epoch 27/150
#
# Epoch 00027: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9641e-05 - mean_squared_error: 1.9641e-05 - val_loss: 2.1579e-05 - val_mean_squared_error: 2.1579e-05
# train-reg
# Localization Error: 0.020186	1.843621	3.49021	6.65271	75.23570
# validation-reg
# Localization Error: 0.020186	1.873309	3.52952	6.90298	74.94956
# Epoch 28/150
#
# Epoch 00028: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9766e-05 - mean_squared_error: 1.9766e-05 - val_loss: 2.1158e-05 - val_mean_squared_error: 2.1158e-05
# train-reg
# Localization Error: 0.039819	1.703436	3.31577	6.51448	66.51941
# validation-reg
# Localization Error: 0.039819	1.730624	3.37562	6.84627	70.50095
# Epoch 29/150
#
# Epoch 00029: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.9735e-05 - mean_squared_error: 1.9735e-05 - val_loss: 2.0364e-05 - val_mean_squared_error: 2.0364e-05
# train-reg
# Localization Error: 0.039336	1.698632	3.44938	6.69969	68.12697
# validation-reg
# Localization Error: 0.039336	1.727602	3.48825	6.95483	68.76481
# Epoch 30/150
#
# Epoch 00030: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 271us/step - loss: 1.9865e-05 - mean_squared_error: 1.9865e-05 - val_loss: 2.0604e-05 - val_mean_squared_error: 2.0604e-05
# train-reg
# Localization Error: 0.030142	1.692722	3.41272	6.59161	67.64272
# validation-reg
# Localization Error: 0.030142	1.707836	3.48550	6.80556	69.37430
# Epoch 31/150
#
# Epoch 00031: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9636e-05 - mean_squared_error: 1.9636e-05 - val_loss: 2.0237e-05 - val_mean_squared_error: 2.0237e-05
# train-reg
# Localization Error: 0.048818	1.752832	3.31919	6.57905	63.78218
# validation-reg
# Localization Error: 0.048818	1.763790	3.36827	6.80329	65.10414
# Epoch 32/150
#
# Epoch 00032: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.9469e-05 - mean_squared_error: 1.9469e-05 - val_loss: 2.0030e-05 - val_mean_squared_error: 2.0030e-05
# train-reg
# Localization Error: 0.029570	1.659741	3.25901	6.52290	63.28492
# validation-reg
# Localization Error: 0.045141	1.677111	3.31351	6.67923	64.50978
# Epoch 33/150
#
# Epoch 00033: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.9556e-05 - mean_squared_error: 1.9556e-05 - val_loss: 1.9974e-05 - val_mean_squared_error: 1.9974e-05
# train-reg
# Localization Error: 0.021188	1.607456	3.17320	6.46525	62.53161
# validation-reg
# Localization Error: 0.021188	1.614535	3.23437	6.64576	68.36735
# Epoch 34/150
#
# Epoch 00034: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9458e-05 - mean_squared_error: 1.9458e-05 - val_loss: 2.0699e-05 - val_mean_squared_error: 2.0699e-05
# train-reg
# Localization Error: 0.053564	1.843512	3.45899	6.70665	64.13122
# validation-reg
# Localization Error: 0.054775	1.850311	3.55704	6.83164	70.02514
# Epoch 35/150
#
# Epoch 00035: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.9423e-05 - mean_squared_error: 1.9423e-05 - val_loss: 2.0471e-05 - val_mean_squared_error: 2.0471e-05
# train-reg
# Localization Error: 0.070175	1.889823	3.43194	6.58975	56.30108
# validation-reg
# Localization Error: 0.070175	1.929022	3.48487	6.75600	66.07373
# Epoch 36/150
#
# Epoch 00036: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9426e-05 - mean_squared_error: 1.9426e-05 - val_loss: 2.0666e-05 - val_mean_squared_error: 2.0666e-05
# train-reg
# Localization Error: 0.023643	1.825399	3.41968	6.68662	59.66409
# validation-reg
# Localization Error: 0.023643	1.847322	3.45053	6.91590	68.27281
# Epoch 37/150
#
# Epoch 00037: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9333e-05 - mean_squared_error: 1.9333e-05 - val_loss: 2.0655e-05 - val_mean_squared_error: 2.0655e-05
# train-reg
# Localization Error: 0.034030	1.776604	3.42859	6.70321	58.89000
# validation-reg
# Localization Error: 0.034030	1.793607	3.51632	7.06178	64.03973
# Epoch 38/150
#
# Epoch 00038: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.9317e-05 - mean_squared_error: 1.9317e-05 - val_loss: 1.9824e-05 - val_mean_squared_error: 1.9824e-05
# train-reg
# Localization Error: 0.028459	1.556810	3.13085	6.38897	59.18707
# validation-reg
# Localization Error: 0.047694	1.536260	3.17457	6.63899	65.82774
# Epoch 39/150
#
# Epoch 00039: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.9258e-05 - mean_squared_error: 1.9258e-05 - val_loss: 2.0149e-05 - val_mean_squared_error: 2.0149e-05
# train-reg
# Localization Error: 0.045270	1.773041	3.31260	6.53850	55.32503
# validation-reg
# Localization Error: 0.087513	1.809928	3.38268	6.80210	64.47641
# Epoch 40/150
#
# Epoch 00040: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.9273e-05 - mean_squared_error: 1.9273e-05 - val_loss: 2.0094e-05 - val_mean_squared_error: 2.0094e-05
# train-reg
# Localization Error: 0.055238	1.668625	3.33922	6.59991	60.23011
# validation-reg
# Localization Error: 0.055238	1.660578	3.35695	6.80371	64.52174
# Epoch 41/150
#
# Epoch 00041: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.9300e-05 - mean_squared_error: 1.9300e-05 - val_loss: 1.9369e-05 - val_mean_squared_error: 1.9369e-05
# train-reg
# Localization Error: 0.028305	1.686653	3.26274	6.49295	57.20095
# validation-reg
# Localization Error: 0.028305	1.701432	3.30387	6.66266	67.42084
# Epoch 42/150
#
# Epoch 00042: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9266e-05 - mean_squared_error: 1.9266e-05 - val_loss: 1.9856e-05 - val_mean_squared_error: 1.9856e-05
# train-reg
# Localization Error: 0.034842	1.532469	3.10409	6.42336	57.14507
# validation-reg
# Localization Error: 0.034842	1.518116	3.18477	6.72692	67.20262
# Epoch 43/150
#
# Epoch 00043: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.9353e-05 - mean_squared_error: 1.9353e-05 - val_loss: 2.1010e-05 - val_mean_squared_error: 2.1010e-05
# train-reg
# Localization Error: 0.058356	1.866511	3.60847	6.93397	57.00518
# validation-reg
# Localization Error: 0.058356	1.917722	3.62089	7.11294	61.40770
# Epoch 44/150
#
# Epoch 00044: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.9231e-05 - mean_squared_error: 1.9231e-05 - val_loss: 2.0299e-05 - val_mean_squared_error: 2.0299e-05
# train-reg
# Localization Error: 0.045020	1.628072	3.28501	6.47720	58.53527
# validation-reg
# Localization Error: 0.045843	1.639873	3.30017	6.67290	64.28949
# Epoch 45/150
#
# Epoch 00045: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.9394e-05 - mean_squared_error: 1.9394e-05 - val_loss: 2.0474e-05 - val_mean_squared_error: 2.0474e-05
# train-reg
# Localization Error: 0.030420	1.866577	3.38765	6.59115	59.42473
# validation-reg
# Localization Error: 0.030420	1.850666	3.41805	6.62239	71.73860
# Epoch 46/150
#
# Epoch 00046: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.9229e-05 - mean_squared_error: 1.9229e-05 - val_loss: 2.0363e-05 - val_mean_squared_error: 2.0363e-05
# train-reg
# Localization Error: 0.081330	2.063484	3.49992	6.60265	60.98042
# validation-reg
# Localization Error: 0.107660	2.056786	3.54281	6.72560	61.98229
# Epoch 47/150
#
# Epoch 00047: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9249e-05 - mean_squared_error: 1.9249e-05 - val_loss: 1.9551e-05 - val_mean_squared_error: 1.9551e-05
# train-reg
# Localization Error: 0.056319	1.496899	3.22288	6.33752	50.78353
# validation-reg
# Localization Error: 0.056319	1.518320	3.23043	6.60786	62.81990
# Epoch 48/150
#
# Epoch 00048: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 270us/step - loss: 1.9166e-05 - mean_squared_error: 1.9166e-05 - val_loss: 2.0400e-05 - val_mean_squared_error: 2.0400e-05
# train-reg
# Localization Error: 0.060300	1.715238	3.23496	6.46673	52.24909
# validation-reg
# Localization Error: 0.060300	1.696628	3.27999	6.61380	65.42525
# Epoch 49/150
#
# Epoch 00049: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.9168e-05 - mean_squared_error: 1.9168e-05 - val_loss: 1.9894e-05 - val_mean_squared_error: 1.9894e-05
# train-reg
# Localization Error: 0.027720	1.881343	3.42039	6.52133	59.18200
# validation-reg
# Localization Error: 0.027720	1.869019	3.47066	6.62217	62.27577
# Epoch 50/150
#
# Epoch 00050: LearningRateScheduler setting learning rate to 9.999999747378752e-06.
# 62528/62528 [==============================] - 17s 271us/step - loss: 1.9238e-05 - mean_squared_error: 1.9238e-05 - val_loss: 1.9817e-05 - val_mean_squared_error: 1.9817e-05
# train-reg
# Localization Error: 0.022110	1.627710	3.17030	6.33804	57.96369
# validation-reg
# Localization Error: 0.022110	1.616435	3.20360	6.61518	66.65775
# Epoch 51/150
#
# Epoch 00051: LearningRateScheduler setting learning rate to 9.999999747378752e-07.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7773e-05 - mean_squared_error: 1.7773e-05 - val_loss: 1.8469e-05 - val_mean_squared_error: 1.8469e-05
# train-reg
# Localization Error: 0.009705	1.104047	2.76177	6.13275	55.69067
# validation-reg
# Localization Error: 0.009705	1.127941	2.79895	6.30012	66.83712
# Epoch 52/150
#
# Epoch 00052: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.7531e-05 - mean_squared_error: 1.7531e-05 - val_loss: 1.8401e-05 - val_mean_squared_error: 1.8401e-05
# train-reg
# Localization Error: 0.032151	1.099642	2.77227	6.14073	53.82598
# validation-reg
# Localization Error: 0.032151	1.101518	2.81191	6.34867	65.95938
# Epoch 53/150
#
# Epoch 00053: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7517e-05 - mean_squared_error: 1.7517e-05 - val_loss: 1.8485e-05 - val_mean_squared_error: 1.8485e-05
# train-reg
# Localization Error: 0.016806	1.100308	2.79732	6.14346	54.91878
# validation-reg
# Localization Error: 0.016806	1.104423	2.84626	6.34124	66.95574
# Epoch 54/150
#
# Epoch 00054: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7517e-05 - mean_squared_error: 1.7517e-05 - val_loss: 1.8473e-05 - val_mean_squared_error: 1.8473e-05
# train-reg
# Localization Error: 0.009317	1.140390	2.80306	6.13454	54.75026
# validation-reg
# Localization Error: 0.009317	1.145871	2.85058	6.35335	66.74417
# Epoch 55/150
#
# Epoch 00055: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 18s 280us/step - loss: 1.7495e-05 - mean_squared_error: 1.7495e-05 - val_loss: 1.8485e-05 - val_mean_squared_error: 1.8485e-05
# train-reg
# Localization Error: 0.032546	1.139833	2.76790	6.14389	56.28165
# validation-reg
# Localization Error: 0.032546	1.123830	2.82305	6.32875	67.14419
# Epoch 56/150
#
# Epoch 00056: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7494e-05 - mean_squared_error: 1.7494e-05 - val_loss: 1.8492e-05 - val_mean_squared_error: 1.8492e-05
# train-reg
# Localization Error: 0.018953	1.100443	2.81820	6.14111	55.25682
# validation-reg
# Localization Error: 0.018953	1.120426	2.84183	6.30073	65.49999
# Epoch 57/150
#
# Epoch 00057: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.7508e-05 - mean_squared_error: 1.7508e-05 - val_loss: 1.8433e-05 - val_mean_squared_error: 1.8433e-05
# train-reg
# Localization Error: 0.004210	1.117558	2.80400	6.15131	55.34697
# validation-reg
# Localization Error: 0.038774	1.126534	2.83058	6.38657	66.41598
# Epoch 58/150
#
# Epoch 00058: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7504e-05 - mean_squared_error: 1.7504e-05 - val_loss: 1.8527e-05 - val_mean_squared_error: 1.8527e-05
# train-reg
# Localization Error: 0.015416	1.127274	2.83142	6.12025	53.92025
# validation-reg
# Localization Error: 0.015416	1.146765	2.84356	6.33297	66.71272
# Epoch 59/150
#
# Epoch 00059: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.7485e-05 - mean_squared_error: 1.7485e-05 - val_loss: 1.8627e-05 - val_mean_squared_error: 1.8627e-05
# train-reg
# Localization Error: 0.012394	1.141545	2.81870	6.14352	54.43521
# validation-reg
# Localization Error: 0.012394	1.183690	2.83257	6.41581	65.46009
# Epoch 60/150
#
# Epoch 00060: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 270us/step - loss: 1.7492e-05 - mean_squared_error: 1.7492e-05 - val_loss: 1.8474e-05 - val_mean_squared_error: 1.8474e-05
# train-reg
# Localization Error: 0.014586	1.127504	2.82556	6.11835	53.63873
# validation-reg
# Localization Error: 0.015751	1.156802	2.88262	6.35783	65.23730
# Epoch 61/150
#
# Epoch 00061: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7485e-05 - mean_squared_error: 1.7485e-05 - val_loss: 1.8440e-05 - val_mean_squared_error: 1.8440e-05
# train-reg
# Localization Error: 0.013249	1.064305	2.77421	6.09488	57.12685
# validation-reg
# Localization Error: 0.013249	1.079245	2.85039	6.31679	66.98543
# Epoch 62/150
#
# Epoch 00062: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.7479e-05 - mean_squared_error: 1.7479e-05 - val_loss: 1.8433e-05 - val_mean_squared_error: 1.8433e-05
# train-reg
# Localization Error: 0.020672	1.068450	2.77185	6.11694	54.51867
# validation-reg
# Localization Error: 0.020672	1.081745	2.78761	6.34878	65.60365
# Epoch 63/150
#
# Epoch 00063: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 271us/step - loss: 1.7481e-05 - mean_squared_error: 1.7481e-05 - val_loss: 1.8421e-05 - val_mean_squared_error: 1.8421e-05
# train-reg
# Localization Error: 0.038573	1.083452	2.78246	6.12090	54.23504
# validation-reg
# Localization Error: 0.038573	1.091257	2.81941	6.31719	66.54231
# Epoch 64/150
#
# Epoch 00064: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 272us/step - loss: 1.7468e-05 - mean_squared_error: 1.7468e-05 - val_loss: 1.8426e-05 - val_mean_squared_error: 1.8426e-05
# train-reg
# Localization Error: 0.039048	1.099459	2.80202	6.10436	53.87559
# validation-reg
# Localization Error: 0.039048	1.104299	2.81682	6.33139	65.38331
# Epoch 65/150
#
# Epoch 00065: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7481e-05 - mean_squared_error: 1.7481e-05 - val_loss: 1.8432e-05 - val_mean_squared_error: 1.8432e-05
# train-reg
# Localization Error: 0.021818	1.078186	2.80893	6.11546	54.08786
# validation-reg
# Localization Error: 0.021818	1.118732	2.83385	6.34061	66.70295
# Epoch 66/150
#
# Epoch 00066: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7479e-05 - mean_squared_error: 1.7479e-05 - val_loss: 1.8510e-05 - val_mean_squared_error: 1.8510e-05
# train-reg
# Localization Error: 0.018750	1.128852	2.80661	6.12942	54.65622
# validation-reg
# Localization Error: 0.018750	1.143530	2.84598	6.37140	65.25074
# Epoch 67/150
#
# Epoch 00067: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7479e-05 - mean_squared_error: 1.7479e-05 - val_loss: 1.8480e-05 - val_mean_squared_error: 1.8480e-05
# train-reg
# Localization Error: 0.036376	1.136700	2.81163	6.15117	52.76266
# validation-reg
# Localization Error: 0.036376	1.166451	2.84608	6.37247	65.30810
# Epoch 68/150
#
# Epoch 00068: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 19s 297us/step - loss: 1.7468e-05 - mean_squared_error: 1.7468e-05 - val_loss: 1.8384e-05 - val_mean_squared_error: 1.8384e-05
# train-reg
# Localization Error: 0.020971	1.095004	2.77865	6.12691	54.79343
# validation-reg
# Localization Error: 0.020971	1.088848	2.81921	6.26015	67.21022
# Epoch 69/150
#
# Epoch 00069: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.7466e-05 - mean_squared_error: 1.7466e-05 - val_loss: 1.8363e-05 - val_mean_squared_error: 1.8363e-05
# train-reg
# Localization Error: 0.016405	1.106981	2.79816	6.13428	54.42525
# validation-reg
# Localization Error: 0.016405	1.121511	2.82567	6.35510	67.09217
# Epoch 70/150
#
# Epoch 00070: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.7470e-05 - mean_squared_error: 1.7470e-05 - val_loss: 1.8476e-05 - val_mean_squared_error: 1.8476e-05
# train-reg
# Localization Error: 0.012867	1.067733	2.73852	6.08065	52.94128
# validation-reg
# Localization Error: 0.012867	1.098984	2.77053	6.32400	65.41637
# Epoch 71/150
#
# Epoch 00071: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.7478e-05 - mean_squared_error: 1.7478e-05 - val_loss: 1.8445e-05 - val_mean_squared_error: 1.8445e-05
# train-reg
# Localization Error: 0.013317	1.076963	2.77980	6.13332	54.61521
# validation-reg
# Localization Error: 0.013317	1.091396	2.81655	6.34371	66.47410
# Epoch 72/150
#
# Epoch 00072: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7476e-05 - mean_squared_error: 1.7476e-05 - val_loss: 1.8456e-05 - val_mean_squared_error: 1.8456e-05
# train-reg
# Localization Error: 0.013089	1.114612	2.80461	6.15130	55.42781
# validation-reg
# Localization Error: 0.013089	1.125411	2.84496	6.37460	68.39676
# Epoch 73/150
#
# Epoch 00073: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7477e-05 - mean_squared_error: 1.7477e-05 - val_loss: 1.8449e-05 - val_mean_squared_error: 1.8449e-05
# train-reg
# Localization Error: 0.008884	1.058439	2.75564	6.12340	54.70954
# validation-reg
# Localization Error: 0.008884	1.095522	2.78629	6.35023	65.63230
# Epoch 74/150
#
# Epoch 00074: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7476e-05 - mean_squared_error: 1.7476e-05 - val_loss: 1.8432e-05 - val_mean_squared_error: 1.8432e-05
# train-reg
# Localization Error: 0.024063	1.101372	2.82164	6.10009	55.76608
# validation-reg
# Localization Error: 0.024063	1.140329	2.83414	6.36758	67.11595
# Epoch 75/150
#
# Epoch 00075: LearningRateScheduler setting learning rate to 9.999999974752427e-07.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7466e-05 - mean_squared_error: 1.7466e-05 - val_loss: 1.8467e-05 - val_mean_squared_error: 1.8467e-05
# train-reg
# Localization Error: 0.017809	1.103565	2.78941	6.09753	54.60355
# validation-reg
# Localization Error: 0.017809	1.143005	2.78725	6.32572	65.24464
# Epoch 76/150
#
# Epoch 00076: LearningRateScheduler setting learning rate to 9.999999974752428e-08.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.7298e-05 - mean_squared_error: 1.7298e-05 - val_loss: 1.8362e-05 - val_mean_squared_error: 1.8362e-05
# train-reg
# Localization Error: 0.020573	1.035533	2.75637	6.03574	53.88695
# validation-reg
# Localization Error: 0.020573	1.046681	2.78148	6.26804	65.86279
# Epoch 77/150
#
# Epoch 00077: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7272e-05 - mean_squared_error: 1.7272e-05 - val_loss: 1.8338e-05 - val_mean_squared_error: 1.8338e-05
# train-reg
# Localization Error: 0.019451	1.034976	2.72770	6.06428	53.82152
# validation-reg
# Localization Error: 0.019451	1.050819	2.77367	6.26140	65.93635
# Epoch 78/150
#
# Epoch 00078: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7267e-05 - mean_squared_error: 1.7267e-05 - val_loss: 1.8339e-05 - val_mean_squared_error: 1.8339e-05
# train-reg
# Localization Error: 0.005901	1.025568	2.73144	6.06452	53.93085
# validation-reg
# Localization Error: 0.005901	1.041922	2.75324	6.26600	66.01553
# Epoch 79/150
#
# Epoch 00079: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 278us/step - loss: 1.7265e-05 - mean_squared_error: 1.7265e-05 - val_loss: 1.8324e-05 - val_mean_squared_error: 1.8324e-05
# train-reg
# Localization Error: 0.005843	1.022353	2.73388	6.03299	53.92720
# validation-reg
# Localization Error: 0.005843	1.035503	2.76238	6.27591	65.84364
# Epoch 80/150
#
# Epoch 00080: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7263e-05 - mean_squared_error: 1.7263e-05 - val_loss: 1.8323e-05 - val_mean_squared_error: 1.8323e-05
# train-reg
# Localization Error: 0.011361	1.031437	2.74844	6.03892	53.98372
# validation-reg
# Localization Error: 0.011361	1.032524	2.77025	6.30568	65.87828
# Epoch 81/150
#
# Epoch 00081: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7262e-05 - mean_squared_error: 1.7262e-05 - val_loss: 1.8333e-05 - val_mean_squared_error: 1.8333e-05
# train-reg
# Localization Error: 0.011741	1.039436	2.75052	6.05227	53.88703
# validation-reg
# Localization Error: 0.011741	1.063182	2.76823	6.28606	65.75919
# Epoch 82/150
#
# Epoch 00082: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7261e-05 - mean_squared_error: 1.7261e-05 - val_loss: 1.8317e-05 - val_mean_squared_error: 1.8317e-05
# train-reg
# Localization Error: 0.034769	1.027329	2.74913	6.03850	53.94193
# validation-reg
# Localization Error: 0.034769	1.044281	2.75921	6.30816	65.89652
# Epoch 83/150
#
# Epoch 00083: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7261e-05 - mean_squared_error: 1.7261e-05 - val_loss: 1.8329e-05 - val_mean_squared_error: 1.8329e-05
# train-reg
# Localization Error: 0.014807	1.035291	2.74649	6.05088	53.99210
# validation-reg
# Localization Error: 0.014807	1.051539	2.74968	6.27046	65.78964
# Epoch 84/150
#
# Epoch 00084: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7261e-05 - mean_squared_error: 1.7261e-05 - val_loss: 1.8319e-05 - val_mean_squared_error: 1.8319e-05
# train-reg
# Localization Error: 0.018433	1.030483	2.75088	6.05784	54.10607
# validation-reg
# Localization Error: 0.018433	1.035929	2.75721	6.30168	65.77248
# Epoch 85/150
#
# Epoch 00085: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 278us/step - loss: 1.7257e-05 - mean_squared_error: 1.7257e-05 - val_loss: 1.8319e-05 - val_mean_squared_error: 1.8319e-05
# train-reg
# Localization Error: 0.011238	1.049039	2.74064	6.04135	54.25921
# validation-reg
# Localization Error: 0.011238	1.051292	2.77549	6.27480	66.34992
# Epoch 86/150
#
# Epoch 00086: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7261e-05 - mean_squared_error: 1.7261e-05 - val_loss: 1.8312e-05 - val_mean_squared_error: 1.8312e-05
# train-reg
# Localization Error: 0.010768	1.040570	2.74067	6.03677	54.23053
# validation-reg
# Localization Error: 0.010768	1.043429	2.75487	6.29830	66.01788
# Epoch 87/150
#
# Epoch 00087: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7260e-05 - mean_squared_error: 1.7260e-05 - val_loss: 1.8313e-05 - val_mean_squared_error: 1.8313e-05
# train-reg
# Localization Error: 0.011707	1.031650	2.74805	6.03549	54.29926
# validation-reg
# Localization Error: 0.011707	1.034494	2.75842	6.25712	65.96800
# Epoch 88/150
#
# Epoch 00088: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7261e-05 - mean_squared_error: 1.7261e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.004260	1.027559	2.74293	6.03230	54.20164
# validation-reg
# Localization Error: 0.004260	1.032635	2.77047	6.30782	65.96552
# Epoch 89/150
#
# Epoch 00089: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7260e-05 - mean_squared_error: 1.7260e-05 - val_loss: 1.8314e-05 - val_mean_squared_error: 1.8314e-05
# train-reg
# Localization Error: 0.032100	1.022260	2.74100	6.05312	54.06108
# validation-reg
# Localization Error: 0.032100	1.041718	2.75042	6.30278	65.67833
# Epoch 90/150
#
# Epoch 00090: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 18s 281us/step - loss: 1.7260e-05 - mean_squared_error: 1.7260e-05 - val_loss: 1.8311e-05 - val_mean_squared_error: 1.8311e-05
# train-reg
# Localization Error: 0.007263	1.033313	2.72785	6.02557	54.20794
# validation-reg
# Localization Error: 0.007263	1.042093	2.76657	6.27084	66.03952
# Epoch 91/150
#
# Epoch 00091: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7259e-05 - mean_squared_error: 1.7259e-05 - val_loss: 1.8313e-05 - val_mean_squared_error: 1.8313e-05
# train-reg
# Localization Error: 0.011197	1.023937	2.74738	6.04174	54.34407
# validation-reg
# Localization Error: 0.011197	1.030595	2.76800	6.28067	65.90397
# Epoch 92/150
#
# Epoch 00092: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 18s 282us/step - loss: 1.7260e-05 - mean_squared_error: 1.7260e-05 - val_loss: 1.8307e-05 - val_mean_squared_error: 1.8307e-05
# train-reg
# Localization Error: 0.003736	1.027739	2.73089	6.04583	54.15246
# validation-reg
# Localization Error: 0.003736	1.042858	2.74694	6.26982	65.92819
# Epoch 93/150
#
# Epoch 00093: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 18s 283us/step - loss: 1.7259e-05 - mean_squared_error: 1.7259e-05 - val_loss: 1.8304e-05 - val_mean_squared_error: 1.8304e-05
# train-reg
# Localization Error: 0.007300	1.010769	2.72932	6.03257	54.15314
# validation-reg
# Localization Error: 0.007300	1.038550	2.75798	6.30479	65.91971
# Epoch 94/150
#
# Epoch 00094: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 18s 283us/step - loss: 1.7256e-05 - mean_squared_error: 1.7256e-05 - val_loss: 1.8314e-05 - val_mean_squared_error: 1.8314e-05
# train-reg
# Localization Error: 0.010223	1.018633	2.75177	6.06040	54.10905
# validation-reg
# Localization Error: 0.010223	1.024218	2.76542	6.26631	65.42931
# Epoch 95/150
#
# Epoch 00095: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 18s 282us/step - loss: 1.7259e-05 - mean_squared_error: 1.7259e-05 - val_loss: 1.8318e-05 - val_mean_squared_error: 1.8318e-05
# train-reg
# Localization Error: 0.002212	1.036688	2.75038	6.04589	54.19628
# validation-reg
# Localization Error: 0.002212	1.036688	2.75996	6.26145	65.66412
# Epoch 96/150
#
# Epoch 00096: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7257e-05 - mean_squared_error: 1.7257e-05 - val_loss: 1.8310e-05 - val_mean_squared_error: 1.8310e-05
# train-reg
# Localization Error: 0.020604	1.016920	2.72267	6.03013	54.12563
# validation-reg
# Localization Error: 0.021245	1.055577	2.74296	6.30993	65.98951
# Epoch 97/150
#
# Epoch 00097: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 278us/step - loss: 1.7257e-05 - mean_squared_error: 1.7257e-05 - val_loss: 1.8314e-05 - val_mean_squared_error: 1.8314e-05
# train-reg
# Localization Error: 0.004258	1.028922	2.74866	6.05842	54.25614
# validation-reg
# Localization Error: 0.004258	1.034387	2.76224	6.27480	65.82884
# Epoch 98/150
#
# Epoch 00098: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7257e-05 - mean_squared_error: 1.7257e-05 - val_loss: 1.8311e-05 - val_mean_squared_error: 1.8311e-05
# train-reg
# Localization Error: 0.013808	1.028040	2.74849	6.03982	54.27524
# validation-reg
# Localization Error: 0.013808	1.036636	2.76131	6.28755	65.92061
# Epoch 99/150
#
# Epoch 00099: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7259e-05 - mean_squared_error: 1.7259e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.014379	1.043819	2.74062	6.05569	54.21773
# validation-reg
# Localization Error: 0.014379	1.055761	2.74711	6.26875	65.67314
# Epoch 100/150
#
# Epoch 00100: LearningRateScheduler setting learning rate to 1.0000000116860974e-07.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7257e-05 - mean_squared_error: 1.7257e-05 - val_loss: 1.8315e-05 - val_mean_squared_error: 1.8315e-05
# train-reg
# Localization Error: 0.022494	1.025837	2.75155	6.04814	54.08140
# validation-reg
# Localization Error: 0.022494	1.049173	2.78558	6.32011	65.55725
# Epoch 101/150
#
# Epoch 00101: LearningRateScheduler setting learning rate to 1.0000000116860975e-08.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7233e-05 - mean_squared_error: 1.7233e-05 - val_loss: 1.8312e-05 - val_mean_squared_error: 1.8312e-05
# train-reg
# Localization Error: 0.004855	1.030306	2.75573	6.03361	54.13428
# validation-reg
# Localization Error: 0.004855	1.041978	2.76185	6.27222	65.62774
# Epoch 102/150
#
# Epoch 00102: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 278us/step - loss: 1.7232e-05 - mean_squared_error: 1.7232e-05 - val_loss: 1.8308e-05 - val_mean_squared_error: 1.8308e-05
# train-reg
# Localization Error: 0.020679	1.022366	2.73762	6.03275	54.16036
# validation-reg
# Localization Error: 0.020679	1.025034	2.75641	6.30500	65.68924
# Epoch 103/150
#
# Epoch 00103: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7232e-05 - mean_squared_error: 1.7232e-05 - val_loss: 1.8307e-05 - val_mean_squared_error: 1.8307e-05
# train-reg
# Localization Error: 0.004281	1.018538	2.73894	6.03088	54.18126
# validation-reg
# Localization Error: 0.004281	1.030857	2.75067	6.30606	65.72499
# Epoch 104/150
#
# Epoch 00104: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7232e-05 - mean_squared_error: 1.7232e-05 - val_loss: 1.8308e-05 - val_mean_squared_error: 1.8308e-05
# train-reg
# Localization Error: 0.004478	1.031437	2.73957	6.03435	54.18191
# validation-reg
# Localization Error: 0.004478	1.037346	2.75283	6.28236	65.73212
# Epoch 105/150
#
# Epoch 00105: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8309e-05 - val_mean_squared_error: 1.8309e-05
# train-reg
# Localization Error: 0.011197	1.035495	2.74432	6.03326	54.18399
# validation-reg
# Localization Error: 0.011197	1.036248	2.74838	6.28305	65.73887
# Epoch 106/150
#
# Epoch 00106: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8307e-05 - val_mean_squared_error: 1.8307e-05
# train-reg
# Localization Error: 0.004564	1.020970	2.73731	6.03214	54.18689
# validation-reg
# Localization Error: 0.004564	1.035155	2.75100	6.29334	65.76124
# Epoch 107/150
#
# Epoch 00107: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.013177	1.022062	2.73595	6.03185	54.19044
# validation-reg
# Localization Error: 0.013177	1.035237	2.75172	6.29357	65.76923
# Epoch 108/150
#
# Epoch 00108: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8307e-05 - val_mean_squared_error: 1.8307e-05
# train-reg
# Localization Error: 0.015298	1.024375	2.74425	6.02924	54.18852
# validation-reg
# Localization Error: 0.015298	1.030456	2.75424	6.29389	65.75491
# Epoch 109/150
#
# Epoch 00109: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007191	1.023489	2.73640	6.03206	54.19060
# validation-reg
# Localization Error: 0.007191	1.033657	2.75484	6.29119	65.77356
# Epoch 110/150
#
# Epoch 00110: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8305e-05 - val_mean_squared_error: 1.8305e-05
# train-reg
# Localization Error: 0.008235	1.026195	2.73198	6.02387	54.19611
# validation-reg
# Localization Error: 0.008235	1.030461	2.74702	6.29431	65.78985
# Epoch 111/150
#
# Epoch 00111: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.009238	1.023475	2.74073	6.03332	54.19749
# validation-reg
# Localization Error: 0.009238	1.033838	2.75246	6.29552	65.78341
# Epoch 112/150
#
# Epoch 00112: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8305e-05 - val_mean_squared_error: 1.8305e-05
# train-reg
# Localization Error: 0.008105	1.023353	2.73581	6.02714	54.19361
# validation-reg
# Localization Error: 0.008105	1.033514	2.75322	6.28981	65.78997
# Epoch 113/150
#
# ...
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006145	1.024038	2.74206	6.03402	54.19742
# validation-reg
# Localization Error: 0.006145	1.032019	2.75072	6.29710	65.78430
# Epoch 114/150
#
# Epoch 00114: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8307e-05 - val_mean_squared_error: 1.8307e-05
# train-reg
# Localization Error: 0.007958	1.029167	2.74788	6.03552	54.21302
# validation-reg
# Localization Error: 0.007958	1.034289	2.74879	6.28172	65.78816
# Epoch 115/150
#
# Epoch 00115: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8307e-05 - val_mean_squared_error: 1.8307e-05
# train-reg
# Localization Error: 0.008488	1.025432	2.74883	6.02916	54.19744
# validation-reg
# Localization Error: 0.008488	1.034935	2.74936	6.28032	65.77688
# Epoch 116/150
#
# Epoch 00116: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007667	1.025315	2.74777	6.03377	54.20402
# validation-reg
# Localization Error: 0.007667	1.032259	2.75123	6.28673	65.78918
# Epoch 117/150
#
# Epoch 00117: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8305e-05 - val_mean_squared_error: 1.8305e-05
# train-reg
# Localization Error: 0.006490	1.025287	2.73815	6.02610	54.20308
# validation-reg
# Localization Error: 0.006490	1.031107	2.74503	6.30005	65.78877
# Epoch 118/150
#
# Epoch 00118: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.005183	1.021961	2.74505	6.02947	54.20483
# validation-reg
# Localization Error: 0.005183	1.031665	2.74922	6.29667	65.78587
# Epoch 119/150
#
# Epoch 00119: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8307e-05 - val_mean_squared_error: 1.8307e-05
# train-reg
# Localization Error: 0.007587	1.024949	2.74988	6.02968	54.20165
# validation-reg
# Localization Error: 0.007587	1.034091	2.75483	6.28391	65.77956
# Epoch 120/150
#
# Epoch 00120: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 277us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007953	1.026634	2.74721	6.02997	54.19920
# validation-reg
# Localization Error: 0.007953	1.028729	2.75059	6.28660	65.77595
# Epoch 121/150
#
# Epoch 00121: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8305e-05 - val_mean_squared_error: 1.8305e-05
# train-reg
# Localization Error: 0.003537	1.026642	2.73902	6.02637	54.20123
# validation-reg
# Localization Error: 0.003537	1.030374	2.74926	6.29997	65.79355
# Epoch 122/150
#
# Epoch 00122: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8305e-05 - val_mean_squared_error: 1.8305e-05
# train-reg
# Localization Error: 0.003703	1.024459	2.73939	6.02691	54.20416
# validation-reg
# Localization Error: 0.003703	1.027047	2.75141	6.29728	65.79223
# Epoch 123/150
#
# Epoch 00123: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.009723	1.024167	2.74901	6.03046	54.20429
# validation-reg
# Localization Error: 0.009723	1.033898	2.75159	6.27840	65.78149
# Epoch 124/150
#
# Epoch 00124: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.004199	1.026188	2.74646	6.02903	54.19269
# validation-reg
# Localization Error: 0.004199	1.031031	2.75147	6.29271	65.78293
# Epoch 125/150
#
# Epoch 00125: LearningRateScheduler setting learning rate to 9.99999993922529e-09.
# 62528/62528 [==============================] - 17s 276us/step - loss: 1.7231e-05 - mean_squared_error: 1.7231e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.008074	1.025543	2.75055	6.03401	54.20148
# validation-reg
# Localization Error: 0.008074	1.032825	2.75210	6.28804	65.78769
# Epoch 126/150
#
# Epoch 00126: LearningRateScheduler setting learning rate to 9.999999939225292e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007846	1.025327	2.75022	6.03389	54.20060
# validation-reg
# Localization Error: 0.007846	1.032409	2.75207	6.28879	65.78762
# Epoch 127/150
#
# Epoch 00127: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007481	1.024812	2.75018	6.03372	54.20092
# validation-reg
# Localization Error: 0.007481	1.031414	2.75149	6.29048	65.78821
# Epoch 128/150
#
# Epoch 00128: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007221	1.024948	2.75050	6.03359	54.20070
# validation-reg
# Localization Error: 0.007221	1.030965	2.75150	6.29083	65.78835
# Epoch 129/150
#
# Epoch 00129: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007177	1.024611	2.75050	6.03361	54.20065
# validation-reg
# Localization Error: 0.007177	1.030448	2.75121	6.29138	65.78885
# Epoch 130/150
#
# Epoch 00130: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007128	1.024720	2.75029	6.03360	54.19996
# validation-reg
# Localization Error: 0.007128	1.030622	2.75124	6.29078	65.78862
# Epoch 131/150
#
# Epoch 00131: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007040	1.024754	2.75029	6.03360	54.20015
# validation-reg
# Localization Error: 0.007040	1.030448	2.75153	6.29109	65.78812
# Epoch 132/150
#
# Epoch 00132: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.007014	1.024927	2.75059	6.03371	54.19986
# validation-reg
# Localization Error: 0.007014	1.030510	2.75143	6.29114	65.78888
# Epoch 133/150
#
# Epoch 00133: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006894	1.025048	2.75067	6.03364	54.20004
# validation-reg
# Localization Error: 0.006894	1.030155	2.75182	6.29171	65.78914
# Epoch 134/150
#
# Epoch 00134: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006801	1.025081	2.75049	6.03358	54.20010
# validation-reg
# Localization Error: 0.006801	1.030094	2.75184	6.29194	65.78885
# Epoch 135/150
#
# Epoch 00135: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006772	1.024916	2.75071	6.03370	54.19918
# validation-reg
# Localization Error: 0.006772	1.030184	2.75153	6.29171	65.78865
# Epoch 136/150
#
# Epoch 00136: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006796	1.025226	2.75053	6.03361	54.19905
# validation-reg
# Localization Error: 0.006796	1.030003	2.75161	6.29169	65.78860
# Epoch 137/150
#
# Epoch 00137: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 18s 280us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006748	1.025062	2.75041	6.03384	54.19891
# validation-reg
# Localization Error: 0.006748	1.030173	2.75144	6.29146	65.78781
# Epoch 138/150
#
# Epoch 00138: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006411	1.024982	2.75011	6.03351	54.19892
# validation-reg
# Localization Error: 0.006411	1.029594	2.75181	6.29179	65.78877
# Epoch 139/150
#
# Epoch 00139: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006507	1.024737	2.74983	6.03326	54.19862
# validation-reg
# Localization Error: 0.006507	1.029482	2.75196	6.29183	65.78760
# Epoch 140/150
#
# Epoch 00140: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006388	1.024606	2.74979	6.03291	54.19895
# validation-reg
# Localization Error: 0.006388	1.029257	2.75238	6.29246	65.78758
# Epoch 141/150
#
# Epoch 00141: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006432	1.024688	2.74962	6.03309	54.19863
# validation-reg
# Localization Error: 0.006432	1.029257	2.75231	6.29218	65.78668
# Epoch 142/150
#
# Epoch 00142: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006484	1.024727	2.74977	6.03342	54.19882
# validation-reg
# Localization Error: 0.006484	1.029369	2.75218	6.29199	65.78678
# Epoch 143/150
#
# Epoch 00143: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 275us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006447	1.024900	2.74991	6.03370	54.19876
# validation-reg
# Localization Error: 0.006447	1.029572	2.75225	6.29154	65.78600
# Epoch 144/150
#
# Epoch 00144: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006401	1.024737	2.74977	6.03330	54.19835
# validation-reg
# Localization Error: 0.006401	1.029274	2.75226	6.29184	65.78605
# Epoch 145/150
#
# Epoch 00145: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006396	1.024720	2.75002	6.03320	54.19868
# validation-reg
# Localization Error: 0.006396	1.028920	2.75273	6.29255	65.78621
# Epoch 146/150
#
# Epoch 00146: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006387	1.024569	2.75019	6.03305	54.19889
# validation-reg
# Localization Error: 0.006387	1.028493	2.75212	6.29298	65.78612
# Epoch 147/150
#
# Epoch 00147: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 273us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8305e-05 - val_mean_squared_error: 1.8305e-05
# train-reg
# Localization Error: 0.006189	1.024837	2.74964	6.03254	54.19843
# validation-reg
# Localization Error: 0.006189	1.028106	2.75173	6.29335	65.78667
# Epoch 148/150
#
# Epoch 00148: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006228	1.024531	2.74956	6.03288	54.19756
# validation-reg
# Localization Error: 0.006228	1.028409	2.75217	6.29314	65.78520
# Epoch 149/150
#
# Epoch 00149: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 278us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8305e-05 - val_mean_squared_error: 1.8305e-05
# train-reg
# Localization Error: 0.006266	1.024465	2.74969	6.03278	54.19792
# validation-reg
# Localization Error: 0.006266	1.028286	2.75201	6.29357	65.78588
# Epoch 150/150
#
# Epoch 00150: LearningRateScheduler setting learning rate to 9.999999717180685e-10.
# 62528/62528 [==============================] - 17s 274us/step - loss: 1.7228e-05 - mean_squared_error: 1.7228e-05 - val_loss: 1.8306e-05 - val_mean_squared_error: 1.8306e-05
# train-reg
# Localization Error: 0.006524	1.024556	2.75015	6.03356	54.19774
# validation-reg
# Localization Error: 0.006524	1.028865	2.75234	6.29304	65.78491

# %% [markdown]
# ## Evaluation

# %%
pred_coords = np.multiply(cnn_model.predict(X_val), range_) + min_    
errors = calculate_localization_errors(pred_coords, all_data['1']['val'][3])

# %%
print(f'Best median localization error on the training set: {trn_clb.best_median:.4f}m')
print(f'Best median localization error on the validation set: {val_clb.best_median:.4f}m')
# Out:
# Best median localization error on the training set: 2.7227m
# Best median localization error on the validation set: 2.7430m

# %%
# %ls       # Copy the name of the model that achieved the lowest median localization error on the validation set that has prefix 'best-validation-reg-*'
# Out:
# best_train-reg_median-2.7227_epoch-95       sample_data/  Testbed2.rar
# best_validation-reg_median-2.7430_epoch-95  Testbed2.csv

# %%
cnn_model = keras.models.load_model('best_validation-reg_median-2.7430_epoch-95')  # paste the name you copied from the above cell
test_pred = np.multiply(cnn_model.predict(X_test), range_) + min_
test_errs = errors = calculate_localization_errors(test_pred, all_data['1']['test'][3])
print(f'Minimum: {np.min(test_errs):.4f}m, 25th Percentile: {np.percentile(test_errs, 25):.4f}m, Median: {np.median(test_errs):.4f}m, 75th: {np.percentile(test_errs, 75):.4f}m, Maximum: {np.max(test_errs):.4f}m')
# Out:
# Minimum: 0.0206m, 25th Percentile: 1.0733m, Median: 2.8167m, 75th: 6.2930m, Maximum: 163.8806m
